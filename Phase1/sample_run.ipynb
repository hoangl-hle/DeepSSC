# %%
# sample run on Kaggle platform
# !python main.py <data_folder> <result_folder>

# !python /kaggle/input/phase1release/main.py  /kaggle/input/deepssc-omics-pretrained-model-and-biomarkers/DeepSSC_data/TCGA_CRC/data crc_results
# Out:
# Loading data...
# Classes:  ['CMS1' 'CMS2' 'CMS3' 'CMS4']
# Weight for these classes: tensor([1.4000, 0.4800, 1.4000, 0.6720])
# Create result directory...
#
# Training DAE for GE data...
#
#
# Training DAE for CNA data...
#
#
# Training fusion model...
#
# Please check results in your result folder!
